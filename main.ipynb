# %%
from src.IrisData import IrisData
data = IrisData()

# %% [markdown]
# # k-means clustering

# %%
from src.KMeansClustering import *
kMeans = KMeansClustering(data, k = 2, maxItr = 100)
kMeans.run()

# %%
import matplotlib.pyplot as plt
plt.plot(kMeans.objFunc, "o-r")
plt.ylabel("Objective Function")
plt.xlabel("Iteration")
plt.show()

# %%
_ = kMeans.plotClusters()

# %% [markdown]
# # Neural Networks

# %%
from src.NeuralNetwork import *

# %%
dataset = data.getData()
dataset.switchToNeuralNetwork()

network = NeuralNetwork(weights=np.asarray([-0.7, -0.5,  1.9,  1.5]))
Training.plotClassification(dataset.getPoints(), network)
records = Training.train(dataset.getPoints(), network, dataset.getLabels(), 1000)
Training.plotClassification(dataset.getPoints(), network)

network = NeuralNetwork(weights=np.asarray([-3.978, -3.467,  5.316, 5.326]))
Training.plotClassification(dataset.getPoints(), network)

iterations, errors = zip(*records)
fig, ax = plt.subplots()
ax.plot(iterations, errors)
ax.set_title("MSE vs Iteration")
ax.set_xlabel("Iteration")
ax.set_ylabel("MSE")
# Out:
# 0 --- [0.079, 0.0368, 0.054, 0.0167] --- 0.4698 --- [-0.77904466 -0.53675697  1.84595198  1.48334066]
# 20 --- [-0.6698, -0.3028, -0.5721, -0.2118] --- 0.4733 --- [-0.96312106 -0.66578418  2.15727153  1.74164709]
# 40 --- [0.0414, 0.0193, 0.0278, 0.0086] --- 0.4888 --- [-1.07071201 -0.76169523  2.53815596  2.01040427]
# 60 --- [-0.2461, -0.1126, -0.2138, -0.081] --- 0.1596 --- [-2.00750276 -1.23157022  2.26962816  2.06723924]
# 80 --- [0.1834, 0.0851, 0.1239, 0.0381] --- 0.3509 --- [-1.81617125 -1.20019325  2.98607707  2.49328825]
# 100 --- [-0.7034, -0.3165, -0.5935, -0.2158] --- 0.4429 --- [-1.98768938 -1.35120882  3.54601237  2.91354957]
# 120 --- [0.4886, 0.2293, 0.3591, 0.1125] --- 0.2922 --- [-3.09009072 -1.93259353  3.34078972  3.06564855]
# 140 --- [0.5263, 0.2437, 0.3689, 0.1126] --- 0.0847 --- [-3.23458788 -2.08067732  3.88962006  3.47208704]
# 160 --- [0.5253, 0.2449, 0.3764, 0.1163] --- 0.1279 --- [-3.5591692  -2.32110502  4.18571049  3.76899449]
# 180 --- [0.4349, 0.2042, 0.3196, 0.1002] --- 0.1118 --- [-3.75133856 -2.50613154  4.47002189  4.03704904]
# 200 --- [0.3289, 0.1547, 0.2464, 0.0779] --- 0.0823 --- [-3.83133571 -2.6236686   4.66286076  4.23375397]
# 220 --- [0.2606, 0.1226, 0.1974, 0.0626] --- 0.0663 --- [-3.86924652 -2.70107626  4.77375773  4.37117187]
# 240 --- [0.2206, 0.1038, 0.1681, 0.0534] --- 0.0582 --- [-3.89481512 -2.76220599  4.8455158   4.47677813]
# 260 --- [0.1927, 0.0908, 0.1473, 0.0469] --- 0.0531 --- [-3.91347186 -2.81483874  4.89847589  4.56408872]
# 280 --- [0.1708, 0.0806, 0.1309, 0.0417] --- 0.0496 --- [-3.92737993 -2.86210074  4.94060828  4.63902025]
# 300 --- [0.1526, 0.0722, 0.1172, 0.0373] --- 0.0469 --- [-3.93779632 -2.90558026  4.97575008  4.70474211]
# 320 --- [0.1368, 0.0648, 0.1052, 0.0335] --- 0.0448 --- [-3.94553788 -2.94619105  5.00605923  4.76321691]
# 340 --- [0.1225, 0.0582, 0.0943, 0.03] --- 0.043 --- [-3.95117052 -2.98450135  5.03287943  4.81578122]
# 360 --- [0.1094, 0.0521, 0.0842, 0.0268] --- 0.0416 --- [-3.95510312 -3.02088362  5.05710982  4.86340873]
# 380 --- [0.0969, 0.0463, 0.0747, 0.0237] --- 0.0403 --- [-3.95763983 -3.0555913   5.07938636  4.90684656]
# 400 --- [0.0849, 0.0407, 0.0654, 0.0207] --- 0.0393 --- [-3.95901217 -3.08880199  5.10017981  4.94669354]
# 420 --- [0.0732, 0.0353, 0.0564, 0.0177] --- 0.0383 --- [-3.95940215 -3.12064448  5.11985189  4.9834495 ]
# 440 --- [0.0616, 0.0299, 0.0474, 0.0148] --- 0.0375 --- [-3.9589647  -3.15121889  5.13868622  5.01754882]
# 460 --- [0.0501, 0.0245, 0.0384, 0.0118] --- 0.0369 --- [-3.95785898 -3.18061739  5.15689819  5.04938424]
# 480 --- [0.0386, 0.0192, 0.0294, 0.0088] --- 0.0363 --- [-3.95630072 -3.20895256  5.17461982  5.0793208 ]
# 500 --- [0.0275, 0.0141, 0.0208, 0.006] --- 0.0359 --- [-3.95463867 -3.2363962   5.19185665  5.10769486]
# 520 --- [0.0177, 0.0095, 0.0131, 0.0034] --- 0.0356 --- [-3.9534066  -3.26320687  5.20844799  5.13479453]
# 540 --- [0.0099, 0.0059, 0.007, 0.0014] --- 0.0354 --- [-3.95321696 -3.28968435  5.22412846  5.16084013]
# 560 --- [0.0048, 0.0035, 0.003, 0.0] --- 0.0353 --- [-3.95444737 -3.31602642  5.23874392  5.18600106]
# 580 --- [0.002, 0.0022, 0.0008, -0.0007] --- 0.0352 --- [-3.95701719 -3.34222372  5.25242295  5.21043667]
# 600 --- [0.0008, 0.0016, -0.0002, -0.001] --- 0.0352 --- [-3.96053898 -3.36812647  5.26548659  5.23430089]
# 620 --- [0.0004, 0.0013, -0.0005, -0.0011] --- 0.0351 --- [-3.96462479 -3.39358385  5.27823801  5.2577134 ]
# 640 --- [0.0003, 0.0013, -0.0006, -0.0011] --- 0.035 --- [-3.96903434 -3.41851199  5.2908604   5.28074589]
# 660 --- [0.0002, 0.0012, -0.0006, -0.0011] --- 0.035 --- [-3.97365746 -3.44288584  5.30343442  5.30343385]
# 680 --- [0.0002, 0.0012, -0.0006, -0.0011] --- 0.0349 --- [-3.97845198 -3.46671063  5.31598755  5.32579433]
# 700 --- [0.0003, 0.0012, -0.0006, -0.0011] --- 0.0349 --- [-3.98340138 -3.4900024   5.32852727  5.34783731]
# 720 --- [0.0003, 0.0011, -0.0006, -0.0011] --- 0.0348 --- [-3.98849673 -3.51277968  5.34105527  5.36957058]
# 740 --- [0.0003, 0.0011, -0.0006, -0.0011] --- 0.0347 --- [-3.99373104 -3.53506096  5.35357187  5.39100123]
# 760 --- [0.0003, 0.0011, -0.0006, -0.001] --- 0.0347 --- [-3.99909787 -3.55686406  5.3660771   5.41213606]
# 780 --- [0.0003, 0.0011, -0.0006, -0.001] --- 0.0346 --- [-4.0045911  -3.5782061   5.3785709   5.43298161]
# 800 --- [0.0003, 0.001, -0.0006, -0.001] --- 0.0346 --- [-4.01020484 -3.59910347  5.3910532   5.45354423]
# 820 --- [0.0003, 0.001, -0.0006, -0.001] --- 0.0345 --- [-4.01593343 -3.61957186  5.40352384  5.47383006]
# 840 --- [0.0003, 0.001, -0.0006, -0.001] --- 0.0345 --- [-4.02177146 -3.63962634  5.4159827   5.49384507]
# 860 --- [0.0003, 0.001, -0.0006, -0.001] --- 0.0344 --- [-4.0277137  -3.65928132  5.42842958  5.51359504]
# 880 --- [0.0003, 0.001, -0.0006, -0.001] --- 0.0344 --- [-4.03375518 -3.67855064  5.4408643   5.53308557]
# 900 --- [0.0003, 0.0009, -0.0006, -0.001] --- 0.0343 --- [-4.03989109 -3.69744756  5.45328663  5.55232211]
# 920 --- [0.0003, 0.0009, -0.0006, -0.0009] --- 0.0343 --- [-4.04611683 -3.7159848   5.46569636  5.57130995]
# 940 --- [0.0003, 0.0009, -0.0006, -0.0009] --- 0.0342 --- [-4.05242799 -3.73417456  5.47809325  5.59005423]
# 960 --- [0.0003, 0.0009, -0.0006, -0.0009] --- 0.0342 --- [-4.05882034 -3.75202855  5.49047705  5.60855995]
# 980 --- [0.0003, 0.0009, -0.0006, -0.0009] --- 0.0342 --- [-4.06528982 -3.769558    5.50284753  5.62683196]
# Text(0, 0.5, 'MSE')

# %%
network = NeuralNetwork(weights=np.asarray([-4.12, -3.91, 5.61, 5.76]))
Training.plotClassification(dataset.getPoints(), network)
print(Training.MSE(dataset.getPoints(), network, dataset.getLabels()))

network = NeuralNetwork(weights=np.asarray([0.076, -0.078, 1.10, 0.73]))
Training.plotClassification(dataset.getPoints(), network)
print(Training.MSE(dataset.getPoints(), network, dataset.getLabels()))
# Out:
# 0.033845995641914005
# 0.49655874348811097
